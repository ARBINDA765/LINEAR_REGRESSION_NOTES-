# %% [markdown]
# # Multicollinearity In Linear Regression

# %%
#Stanard error between independent feature will be lower
#Adjusted r squared value will be close to  1
#Check the co-efficent of the independent Features
#P value should be less than .05
#Find the co-relation between between two independent feature
#Either donot do anything with the data 
#Neither check the P value & drop the independent  having high p value

# %%
#Importing the packages
import pandas as pd
import numpy as np
import statsmodels.api as sm

# %%
#Reading the dataset 
df_adv=pd.read_csv("Advertising.csv",index_col=0)
df_adv.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
#Independent Features
X =df_adv[["TV", "Radio","Newspaper"]]
#Dependent Features
y = df_adv['Sales']

# %%
#Adding the constrant to the X 
X = sm.add_constant(X)

# %%
X
# Out:
#      const     TV  Radio  Newspaper
# 1      1.0  230.1   37.8       69.2
# 2      1.0   44.5   39.3       45.1
# 3      1.0   17.2   45.9       69.3
# 4      1.0  151.5   41.3       58.5
# 5      1.0  180.8   10.8       58.4
# ..     ...    ...    ...        ...
# 196    1.0   38.2    3.7       13.8
# 197    1.0   94.2    4.9        8.1
# 198    1.0  177.0    9.3        6.4
# 199    1.0  283.6   42.0       66.2
# 200    1.0  232.1    8.6        8.7
#
# [200 rows x 4 columns]

# %%
## fit a OLS model with intercept on TV and Radio
model=sm.OLS(y,X).fit()

# %%
#Getting the summary
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):           1.58e-96
# Time:                        10:31:48   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.9389      0.312      9.422      0.000       2.324       3.554
# ...

# %%
import matplotlib.pyplot as plt
X.iloc[:,1:].corr()
# Out:
#                  TV     Radio  Newspaper
# TV         1.000000  0.054809   0.056648
# Radio      0.054809  1.000000   0.354104
# Newspaper  0.056648  0.354104   1.000000

# %%
#Salary dataset
df_salary = pd.read_csv('50_Startups.csv')
df_salary.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
#Independent feature
X = df_salary[['R&D Spend',"Administration","Marketing Spend"]]
#Dependent features
y = df_salary['Profit']

# %%
df_salary.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
#ADDING CONSTRAINT TO X
X = sm.add_constant(X)
model= sm.OLS(y, X).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Sat, 21 Nov 2020   Prob (F-statistic):           4.53e-30
# Time:                        10:52:52   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
X.iloc[:,1:].corr()
#Here u can drop the Administration	& Marketing Spend can drop as its in negative
# Out:
#                  R&D Spend  Administration  Marketing Spend
# R&D Spend         1.000000        0.241955         0.724248
# Administration    0.241955        1.000000        -0.032154
# Marketing Spend   0.724248       -0.032154         1.000000
